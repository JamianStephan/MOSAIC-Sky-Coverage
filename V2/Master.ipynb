# %%
import load_field #fieldname,maglimit -> stars_data
import GAIA_query #ra,dec,maglimit -> stars_data
import FOVsim_v3 #stars3_data -> graphical display
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
stars_data=GAIA_query.GAIA_query(30,30,16)
a=FOVsim_v3.FOV_stars(stars_data)
a.run(30,30, report=True,view=True, LGS_angle=18)
# stars_data=GAIA_query.GAIA_query(30,30,18)
# a=FOVsim_v3.FOV_stars(stars_data)

# a.run(30,30, report=True,view=True, LGS_angle=30)
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
# 12.1109705
# 12.610321
# 13.379401
# 13.458195
# 14.275248
# 14.644717
# 15.213595
# 15.446837
# 15.45014
# 15.817896
# 10.83084
# 13.741144
# 14.451253
# 15.397813
# [5, 8, 14, 15, 29, 39, 54, 61, 62, 2, 21, 32, 58]
# [2, 5, 8, 14, 15, 21, 29, 32, 39, 54, 58, 61, 62]
# Minimum NGS distance overridden
# PFS stars available = 3
# PFS stars in LGS footprints = 0
# NGS asterism area = 0.01 arcmin^2
# NGS barycentre distance from centre = 2.6 arcmin
# Overlap of PFS arm and footprint 3: 0.35 arcmin^2
# Overlap of PFS arm and footprint 2: 0.27 arcmin^2
# Overlap of PFS arm and footprint 0: 0.0 arcmin^2
#
# Time taken = 0.0012s

# %%
import time
stars_data=GAIA_query.GAIA_query(54.1,-27.8,18)
start=time.time()
a=FOVsim_v3.FOV_stars(stars_data)

a.run(54.1,-27.8, report=True,view=True, LGS_angle=18,override=True)
period=time.time()-start
print(period)
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
# 12.553504
# 13.926642
# 14.266542
# 15.78866
# 16.056576
# 16.33769
# 17.010891
# 17.370289
# 17.965542
# 17.96747
# 12.709394
# 13.708791
# 14.418877
# 15.361967
# 16.952448
# 17.15892
# 17.510576
# 17.518291
# 17.53684
# [4, 15, 16, 6, 14, 17, 26]
# [4, 6, 14, 15, 16, 17, 26]
# PFS stars available = 3
# PFS stars in LGS footprints = 0
# NGS asterism area = 3.9 arcmin^2
# NGS barycentre distance from centre = 1.2 arcmin
# Overlap of PFS arm and footprint 2: 0.011 arcmin^2
# Overlap of PFS arm and footprint 0: 0.0 arcmin^2
# Overlap of PFS arm and footprint 1: 0.38 arcmin^2
#
# Time taken = 0.0012s
# 0.049713850021362305

# %%
a.run(54.1,-27.8, report=True,view=True, LGS_angle=33)
# Out:
# 12.553504
# 13.926642
# 14.266542
# 15.78866
# 16.056576
# 16.33769
# 17.010891
# 17.370289
# 17.965542
# 17.96747
# 12.709394
# 13.708791
# 14.418877
# 15.361967
# 16.952448
# 17.15892
# 17.510576
# 17.518291
# 17.53684
# [4, 15, 16, 6, 14, 17, 26]
# [4, 6, 14, 15, 16, 17, 26]
# PFS stars available = 3
# PFS stars in LGS footprints = 0
# NGS asterism area = 3.9 arcmin^2
# NGS barycentre distance from centre = 1.2 arcmin
# Overlap of PFS arm and footprint 2: 0.025 arcmin^2
# Overlap of PFS arm and footprint 0: 0.0 arcmin^2
# Overlap of PFS arm and footprint 0: 0.0 arcmin^2
#
# Time taken = 0.0014s

# %%
stars_data=GAIA_query.GAIA_query(30,30,17)
a=FOV_simulator.FOV_stars(stars_data)
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wy/_1rg4fp57c90gdvfqnh0r54m0000gq/T/ipykernel_14004/4169031581.py in <module>
#       1 stars_data=GAIA_query.GAIA_query(30,30,17)
# ----> 2 a=FOV_simulator.FOV_stars(stars_data)
#
# NameError: name 'FOV_simulator' is not defined

# %%
a.run(30,30, report=True,view=True, LGS_angle=0)

# %%
a=[34,6,3,5,3]
a.remove(6),a.remove(5)

# %%
print(a)

# %%
indexes=[3,6,8,2,9,4]
pos=[1,1,3,3,6,6]

# %%
chosen=[]
chosen.append(indexes[0])

# %%
for i in range(1,len(indexes)):
    if abs(pos[0]-pos[i])>1:
        chosen.append(indexes[i])
        break

for o in range(i,len(indexes)):
    if abs(pos[0]-pos[o])>1 and abs(pos[i]-pos[o])>1:
        chosen.append(indexes[o])
        break

# %%
print(chosen)
