# %%
import load_field #fieldname,maglimit -> stars_data
import GAIA_query #ra,dec,maglimit -> stars_data
import FOV_simulator #stars_data -> graphical display
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
stars_data=GAIA_query.GAIA_query(53.16571426,-27.89375114,19)
a=FOV_simulator.FOV_stars(stars_data)
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]

# %%
a.run(53.16571426,-27.89375114, report=True,view=True, LGS_angle=20)
# Out:
# Conv stars:
# 0.0008358955383300781
# Find stars:
# 0.00018405914306640625
# LGS footprint stars:
# 9.989738464355469e-05
# PFS arm stars:
# 0.00011491775512695312
# NGS stars:
# 1.2159347534179688e-05
# One inside
# One inside
# 2
# 7
# 9
# 3
# Stars in FOV = 23
# Stars obscured by LGS footprints = 9
# LGS footprint obscured stars lie in = [2, 2, 2, 3, 4, 1, 3, 2, 2]
# PFS stars available = 3
# Stars vignetted by PFS arms = 2
# NGS stars available = 7
# NGS asterism area = 7.0 arcmin^2
# NGS barycentre distance from centre = 1.6 arcmin
#
# Time taken = 0.0014s

# %%
stars_data=load_field.load_field("CANDLES2",17)
a=FOV_simulator.FOV_stars(stars_data)

# %%
a.run(54.1,-27.8, report=True,view=True, LGS_angle=10)
# Out:
# Conv stars:
# 0.03553318977355957
# Find stars:
# 0.008659839630126953
# LGS footprint stars:
# 7.295608520507812e-05
# PFS arm stars:
# 8.511543273925781e-05
# NGS stars:
# 1.1920928955078125e-05
# One inside
# Two inside
# 1
# 5
# 5
# 3
# Stars in FOV = 14
# Stars obscured by LGS footprints = 5
# LGS footprint obscured stars lie in = [3, 3, 3, 1, 4]
# PFS stars available = 3
# Stars vignetted by PFS arms = 0
# NGS stars available = 5
# NGS asterism area = 3.0 arcmin^2
# NGS barycentre distance from centre = 1.1 arcmin
#
# Time taken = 0.045s

# %%
stars_data=GAIA_query.GAIA_query(30,30,17)
a=FOV_simulator.FOV_stars(stars_data)
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]

# %%
a.run(30,30, report=True,view=True, LGS_angle=0)
# Out:
# Conv stars:
# 0.0010459423065185547
# Find stars:
# 0.0002338886260986328
# LGS footprint stars:
# 0.00011110305786132812
# PFS arm stars:
# 0.00012612342834472656
# NGS stars:
# 1.1920928955078125e-05
# One inside
# One inside
# 6
# 8
# 10
# 3
# Stars in FOV = 27
# Stars obscured by LGS footprints = 10
# LGS footprint obscured stars lie in = [4, 1, 2, 1, 4, 3, 2, 3, 3, 1]
# PFS stars available = 3
# Stars vignetted by PFS arms = 0
# NGS stars available = 8
# NGS asterism area = 0.01 arcmin^2
# NGS barycentre distance from centre = 2.6 arcmin
#
# Time taken = 0.0017s
